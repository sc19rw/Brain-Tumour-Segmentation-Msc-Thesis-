# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import gzip, shutil
import nibabel as nib

import torch.nn.functional as F
from torch import nn as nn
from torch.autograd import Variable
from torch.nn import MSELoss, SmoothL1Loss, L1Loss

# %% [markdown]
# ### Data collection

# %%
def get_IDs():
  root = '/nobackup/sc19rw/Train/HGG' #change this to correct path
  dirlistHGG = [ ("HGG/"+ item + "/" + item) for item in os.listdir(root) if os.path.isdir(os.path.join(root, item)) ]
  root = '/nobackup/sc19rw/Train/LGG' #change this to correct path
  dirlistLGG = [ ("LGG/"+ item + "/" + item) for item in os.listdir(root) if os.path.isdir(os.path.join(root, item)) ]
  total = dirlistHGG + dirlistLGG
  return total

# %%
#MRI_ids = get_IDs()
#random.shuffle(MRI_ids)

# %%
#MRI_ids = np.array(MRI_ids)
#np.savez("/content/drive/My Drive/Project Msc/MRI_ids", MRI_ids)

# %%
MRI_ids = np.load("/home/home01/sc19rw/MRI_ids.npz") #make sure you use the .npz!
MRI_ids = MRI_ids['arr_0']

# %%
import pandas as pd
import random


root = '/nobackup/sc19rw/Train/'

data = {
    'image_id': MRI_ids,
    't1_path': [root + MRI_id + "_t1"+ ".nii" for MRI_id in MRI_ids],
    't1ce_path': [root + MRI_id + "_t1ce" + ".nii" for MRI_id in MRI_ids],
    'flair_path': [root + MRI_id + "_flair" + ".nii" for MRI_id in MRI_ids],
    't2_path': [root + MRI_id + "_t2" + ".nii" for MRI_id in MRI_ids],
    'seg_path': [root + MRI_id + "_seg" + ".nii" for MRI_id in MRI_ids],
}

data_df = pd.DataFrame(data, columns=['image_id', 't1_path', 't1ce_path', 'flair_path', 't2_path', 'seg_path'])

# %%
from torch.utils.data import Dataset
import torch

class BRATS_DATA(Dataset):
    """ BRATS custom dataset compatible with torch.utils.data.DataLoader. """
    
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __getitem__(self, index):

        MRI_id = self.df['image_id'][index] 
        t1_path = self.df['t1_path'][index]
        t1ce_path = self.df['t1ce_path'][index]
        flair_path = self.df['flair_path'][index]
        t2_path = self.df['t2_path'][index]


        t1_MRI = nib.load(t1_path)
        t1ce_MRI = nib.load(t1ce_path)
        flair_MRI = nib.load(flair_path)
        t2_MRI = nib.load(t2_path)

        affines = [t1_MRI.affine, t1ce_MRI.affine, flair_MRI.affine, t2_MRI.affine]

        t1_MRI = t1_MRI.get_fdata()[:,:,:].reshape(1, 240, 240, 155)
        t1ce_MRI = t1ce_MRI.get_fdata()[:,:,:].reshape(1, 240, 240, 155)
        flair_MRI = flair_MRI.get_fdata()[:,:,:].reshape(1, 240, 240, 155)
        t2_MRI = t2_MRI.get_fdata()[:,:,:].reshape(1, 240, 240, 155)

        input_tensor = torch.cat((torch.from_numpy(t1_MRI), torch.from_numpy(t1ce_MRI), torch.from_numpy(flair_MRI), torch.from_numpy(t2_MRI)), 0)
        

        return input_tensor, affines, MRI_id

    def __len__(self):
        return len(self.df)

# %%
dataset = BRATS_DATA(
    df=data_df[:len(data_df)].reset_index(drop=True),
)

# %%
# ADD DATA LOADERS
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=1,
    shuffle=False,
    num_workers=0, 
)

# %%
import statistics 

def normalise_MRI(modality, dimx=240, dimy=240, dimz=155):  #ONE OFF THEN SAVE MRIs do this on full MRIS
  all_values = [] #contains values of all non brain voxels #each modality idenpendently
  for j in range(dimx):
    for k in range(dimy):
      for l in range(dimz):
        if modality[j][k][l].item() != 0.:
          all_values.append(modality[j][k][l].item())
  mean = statistics.mean(all_values)
  stddev = statistics.stdev(all_values)

  for j in range(dimx):
    for k in range(dimy):
      for l in range(dimz):
        if modality[j][k][l].item() != 0.:
          modality[j][k][l] = (modality[j][k][l]- mean) / stddev
  print(torch.max(modality))
  return modality

# %%
def save_normalised():
  for patient, (input_tensor, affines, MRI_ID) in enumerate(data_loader): #ONLY WORKS WITH BATCH SIZE 1
    if patient > 283:
      for i in range(4):
        if i == 0:
          t1_MRI = normalise_MRI(input_tensor[0][i])
          ni_img = nib.Nifti1Image(t1_MRI.numpy(), affines[i].reshape(4, 4))
          nib.save(ni_img, '/nobackup/sc19rw/Train/' + str(MRI_ID[0]) +'_t1_norm.nii')
        elif i == 1: 
          t1ce_MRI = normalise_MRI(input_tensor[0][i])
          ni_img = nib.Nifti1Image(t1ce_MRI.numpy(), affines[i].reshape(4, 4))
          nib.save(ni_img, '/nobackup/sc19rw/Train/' + str(MRI_ID[0]) +'_t1ce_norm.nii')
        elif i == 2: 
          flair_MRI = normalise_MRI(input_tensor[0][i])
          ni_img = nib.Nifti1Image(flair_MRI.numpy(), affines[i].reshape(4, 4))
          nib.save(ni_img, '/nobackup/sc19rw/Train/' + str(MRI_ID[0]) +'_flair_norm.nii')
        elif i == 3: 
          t2_MRI = normalise_MRI(input_tensor[0][i])
          ni_img = nib.Nifti1Image(t2_MRI.numpy(), affines[i].reshape(4, 4))
          nib.save(ni_img, '/nobackup/sc19rw/Train/' + str(MRI_ID[0]) +'_t2_norm.nii')
      print(patient)

# %%
save_normalised()
# Out:
# tensor(3.5815, dtype=torch.float64)
# tensor(12.3698, dtype=torch.float64)
# tensor(10.3593, dtype=torch.float64)
# tensor(5.3255, dtype=torch.float64)
# 284

# %% [markdown]
# ### Testing

# %%
MRI_ids = np.load("/home/home01/sc19rw/MRI_ids.npz") #make sure you use the .npz!
MRI_ids = MRI_ids['arr_0']

# %%
import pandas as pd
import random



#random.shuffle(MRI_ids)
root = '/nobackup/sc19rw/Train/'

data = {
    'image_id': MRI_ids,
    't1_path': [root + MRI_id + "_t1_norm"+ ".nii" for MRI_id in MRI_ids],
    't1ce_path': [root + MRI_id + "_t1ce_norm" + ".nii" for MRI_id in MRI_ids],
    'flair_path': [root + MRI_id + "_flair_norm" + ".nii" for MRI_id in MRI_ids],
    't2_path': [root + MRI_id + "_t2_norm" + ".nii" for MRI_id in MRI_ids],
    'seg_path': [root + MRI_id + "_seg_norm" + ".nii" for MRI_id in MRI_ids],
}

data_df = pd.DataFrame(data, columns=['image_id', 't1_path', 't1ce_path', 'flair_path', 't2_path', 'seg_path'])

# %%
from torch.utils.data import Dataset
import torch

class BRATS_DATA(Dataset):
    """ BRATS custom dataset compatible with torch.utils.data.DataLoader. """
    
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __getitem__(self, index):

        MRI_id = self.df['image_id'][index] 
        t1_path = self.df['t1_path'][index]
        t1ce_path = self.df['t1ce_path'][index]
        flair_path = self.df['flair_path'][index]
        t2_path = self.df['t2_path'][index]


        t1_MRI = nib.load(t1_path)
        t1ce_MRI = nib.load(t1ce_path)
        flair_MRI = nib.load(flair_path)
        t2_MRI = nib.load(t2_path)

        affines = [t1_MRI.affine, t1ce_MRI.affine, flair_MRI.affine, t2_MRI.affine]

        t1_MRI = t1_MRI.get_fdata()[:,:,:].reshape(1, 240, 240, 155)
        t1ce_MRI = t1ce_MRI.get_fdata()[:,:,:].reshape(1, 240, 240, 155)
        flair_MRI = flair_MRI.get_fdata()[:,:,:].reshape(1, 240, 240, 155)
        t2_MRI = t2_MRI.get_fdata()[:,:,:].reshape(1, 240, 240, 155)

        input_tensor = torch.cat((torch.from_numpy(t1_MRI), torch.from_numpy(t1ce_MRI), torch.from_numpy(flair_MRI), torch.from_numpy(t2_MRI)), 0)
        

        return input_tensor, affines, MRI_id

    def __len__(self):
        return len(self.df)

# %%
dataset = BRATS_DATA(
    df=data_df[:len(data_df)].reset_index(drop=True),
)

# %%
# ADD DATA LOADERS
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=1,
    shuffle=False,
    num_workers=0, 
)

# %%
for patient, (input_tensor, affines, MRI_ID) in enumerate(data_loader): #ONLY WORKS WITH BATCH SIZE 1
  print(MRI_ID)
  print(torch.max(input_tensor))
# Out:
# ('HGG/Brats18_TCIA02_117_1/Brats18_TCIA02_117_1',)
# tensor(7.6134, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_625_1/Brats18_TCIA10_625_1',)
# tensor(11.9287, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_280_1/Brats18_TCIA08_280_1',)
# tensor(14.8424, dtype=torch.float64)
# ('HGG/Brats18_CBICA_BFB_1/Brats18_CBICA_BFB_1',)
# tensor(12.6173, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_242_1/Brats18_TCIA08_242_1',)
# tensor(13.9873, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_608_1/Brats18_TCIA02_608_1',)
# tensor(12.9000, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQR_1/Brats18_CBICA_AQR_1',)
# tensor(11.9386, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_460_1/Brats18_TCIA01_460_1',)
# tensor(16.9064, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_471_1/Brats18_TCIA02_471_1',)
# tensor(12.0586, dtype=torch.float64)
# ('HGG/Brats18_2013_7_1/Brats18_2013_7_1',)
# tensor(11.5081, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AVV_1/Brats18_CBICA_AVV_1',)
# tensor(7.7101, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ABM_1/Brats18_CBICA_ABM_1',)
# tensor(11.5543, dtype=torch.float64)
# ('HGG/Brats18_TCIA04_328_1/Brats18_TCIA04_328_1',)
# tensor(13.8281, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_198_1/Brats18_TCIA02_198_1',)
# tensor(9.9913, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AOD_1/Brats18_CBICA_AOD_1',)
# tensor(10.5403, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_442_1/Brats18_TCIA10_442_1',)
# tensor(8.3661, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_621_1/Brats18_TCIA13_621_1',)
# tensor(8.2420, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQN_1/Brats18_CBICA_AQN_1',)
# tensor(11.6230, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_265_1/Brats18_TCIA03_265_1',)
# tensor(16.5835, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_493_1/Brats18_TCIA09_493_1',)
# tensor(16.5814, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ARZ_1/Brats18_CBICA_ARZ_1',)
# tensor(13.4171, dtype=torch.float64)
# ('HGG/Brats18_TCIA04_361_1/Brats18_TCIA04_361_1',)
# tensor(12.8049, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AWH_1/Brats18_CBICA_AWH_1',)
# tensor(12.1388, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_375_1/Brats18_TCIA03_375_1',)
# tensor(14.7225, dtype=torch.float64)
# ('LGG/Brats18_2013_28_1/Brats18_2013_28_1',)
# tensor(11.1557, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AXW_1/Brats18_CBICA_AXW_1',)
# tensor(10.9173, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_370_1/Brats18_TCIA02_370_1',)
# tensor(12.4465, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ANG_1/Brats18_CBICA_ANG_1',)
# tensor(12.8122, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_276_1/Brats18_TCIA10_276_1',)
# tensor(8.6105, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ALN_1/Brats18_CBICA_ALN_1',)
# tensor(12.8658, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ABY_1/Brats18_CBICA_ABY_1',)
# tensor(17.2254, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_377_1/Brats18_TCIA02_377_1',)
# tensor(11.4624, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_605_1/Brats18_TCIA02_605_1',)
# tensor(8.7689, dtype=torch.float64)
# ('HGG/Brats18_CBICA_BHM_1/Brats18_CBICA_BHM_1',)
# tensor(12.7676, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_436_1/Brats18_TCIA08_436_1',)
# tensor(12.3458, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AZH_1/Brats18_CBICA_AZH_1',)
# tensor(11.9707, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AYA_1/Brats18_CBICA_AYA_1',)
# tensor(10.7169, dtype=torch.float64)
# ('HGG/Brats18_TCIA06_603_1/Brats18_TCIA06_603_1',)
# tensor(10.6963, dtype=torch.float64)
# ('HGG/Brats18_2013_4_1/Brats18_2013_4_1',)
# tensor(11.8538, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ATD_1/Brats18_CBICA_ATD_1',)
# tensor(13.1705, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AXQ_1/Brats18_CBICA_AXQ_1',)
# tensor(13.7121, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_634_1/Brats18_TCIA13_634_1',)
# tensor(12.7844, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_474_1/Brats18_TCIA03_474_1',)
# tensor(11.3357, dtype=torch.float64)
# ('LGG/Brats18_2013_24_1/Brats18_2013_24_1',)
# tensor(6.9617, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQA_1/Brats18_CBICA_AQA_1',)
# tensor(10.2531, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_607_1/Brats18_TCIA02_607_1',)
# tensor(13.7787, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_296_1/Brats18_TCIA03_296_1',)
# tensor(17.3547, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AYI_1/Brats18_CBICA_AYI_1',)
# tensor(11.2708, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AUN_1/Brats18_CBICA_AUN_1',)
# tensor(11.6815, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_167_1/Brats18_TCIA08_167_1',)
# tensor(12.0708, dtype=torch.float64)
# ('HGG/Brats18_TCIA04_111_1/Brats18_TCIA04_111_1',)
# tensor(13.3343, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_180_1/Brats18_TCIA01_180_1',)
# tensor(12.1650, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ALX_1/Brats18_CBICA_ALX_1',)
# tensor(11.1946, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ATV_1/Brats18_CBICA_ATV_1',)
# tensor(10.0588, dtype=torch.float64)
# ('HGG/Brats18_TCIA06_211_1/Brats18_TCIA06_211_1',)
# tensor(12.3524, dtype=torch.float64)
# ('LGG/Brats18_TCIA12_249_1/Brats18_TCIA12_249_1',)
# tensor(12.7391, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_637_1/Brats18_TCIA10_637_1',)
# tensor(9.1396, dtype=torch.float64)
# ('LGG/Brats18_2013_6_1/Brats18_2013_6_1',)
# tensor(5.5662, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AWI_1/Brats18_CBICA_AWI_1',)
# tensor(12.2655, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_121_1/Brats18_TCIA03_121_1',)
# tensor(17.6896, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_226_1/Brats18_TCIA02_226_1',)
# tensor(11.8839, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AXO_1/Brats18_CBICA_AXO_1',)
# tensor(14.0168, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_408_1/Brats18_TCIA10_408_1',)
# tensor(18.8166, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_654_1/Brats18_TCIA13_654_1',)
# tensor(8.4784, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_171_1/Brats18_TCIA02_171_1',)
# tensor(10.8307, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQZ_1/Brats18_CBICA_AQZ_1',)
# tensor(11.8677, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_330_1/Brats18_TCIA10_330_1',)
# tensor(10.7864, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_335_1/Brats18_TCIA01_335_1',)
# tensor(11.0830, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_118_1/Brats18_TCIA02_118_1',)
# tensor(10.8166, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_103_1/Brats18_TCIA10_103_1',)
# tensor(7.8677, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AVJ_1/Brats18_CBICA_AVJ_1',)
# tensor(10.3821, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_131_1/Brats18_TCIA01_131_1',)
# tensor(9.5260, dtype=torch.float64)
# ('HGG/Brats18_2013_2_1/Brats18_2013_2_1',)
# tensor(10.8175, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ATP_1/Brats18_CBICA_ATP_1',)
# tensor(14.0712, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQP_1/Brats18_CBICA_AQP_1',)
# tensor(12.1730, dtype=torch.float64)
# ('HGG/Brats18_2013_13_1/Brats18_2013_13_1',)
# tensor(6.9432, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_205_1/Brats18_TCIA08_205_1',)
# tensor(12.1889, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_254_1/Brats18_TCIA09_254_1',)
# tensor(11.4860, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASW_1/Brats18_CBICA_ASW_1',)
# tensor(12.5772, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AME_1/Brats18_CBICA_AME_1',)
# tensor(11.6708, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AAB_1/Brats18_CBICA_AAB_1',)
# tensor(13.0747, dtype=torch.float64)
# ('HGG/Brats18_TCIA04_437_1/Brats18_TCIA04_437_1',)
# tensor(11.5725, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_620_1/Brats18_TCIA09_620_1',)
# tensor(10.5438, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_309_1/Brats18_TCIA02_309_1',)
# tensor(13.7162, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_629_1/Brats18_TCIA10_629_1',)
# tensor(12.7948, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_190_1/Brats18_TCIA01_190_1',)
# tensor(11.4352, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASV_1/Brats18_CBICA_ASV_1',)
# tensor(13.2116, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_222_1/Brats18_TCIA02_222_1',)
# tensor(9.0572, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AVG_1/Brats18_CBICA_AVG_1',)
# tensor(14.6613, dtype=torch.float64)
# ('HGG/Brats18_2013_27_1/Brats18_2013_27_1',)
# tensor(7.8579, dtype=torch.float64)
# ('HGG/Brats18_TCIA04_149_1/Brats18_TCIA04_149_1',)
# tensor(9.1177, dtype=torch.float64)
# ('HGG/Brats18_CBICA_BHB_1/Brats18_CBICA_BHB_1',)
# tensor(16.2536, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AXJ_1/Brats18_CBICA_AXJ_1',)
# tensor(12.9966, dtype=torch.float64)
# ('HGG/Brats18_TCIA05_444_1/Brats18_TCIA05_444_1',)
# tensor(9.2265, dtype=torch.float64)
# ('HGG/Brats18_CBICA_APZ_1/Brats18_CBICA_APZ_1',)
# tensor(10.5654, dtype=torch.float64)
# ('HGG/Brats18_2013_25_1/Brats18_2013_25_1',)
# tensor(11.2848, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AUQ_1/Brats18_CBICA_AUQ_1',)
# tensor(10.7586, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_394_1/Brats18_TCIA02_394_1',)
# tensor(8.6336, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_175_1/Brats18_TCIA10_175_1',)
# tensor(16.1360, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AAL_1/Brats18_CBICA_AAL_1',)
# tensor(12.8626, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AWG_1/Brats18_CBICA_AWG_1',)
# tensor(10.3763, dtype=torch.float64)
# ('LGG/Brats18_2013_0_1/Brats18_2013_0_1',)
# tensor(18.7522, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_449_1/Brats18_TCIA10_449_1',)
# tensor(12.7533, dtype=torch.float64)
# ('HGG/Brats18_TCIA06_184_1/Brats18_TCIA06_184_1',)
# tensor(8.3973, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_282_1/Brats18_TCIA10_282_1',)
# tensor(12.5473, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_133_1/Brats18_TCIA03_133_1',)
# tensor(13.1823, dtype=torch.float64)
# ('HGG/Brats18_2013_22_1/Brats18_2013_22_1',)
# tensor(9.7950, dtype=torch.float64)
# ('HGG/Brats18_2013_20_1/Brats18_2013_20_1',)
# tensor(10.1978, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AMH_1/Brats18_CBICA_AMH_1',)
# tensor(12.1137, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_469_1/Brats18_TCIA08_469_1',)
# tensor(11.6451, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_130_1/Brats18_TCIA10_130_1',)
# tensor(9.0277, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASG_1/Brats18_CBICA_ASG_1',)
# tensor(11.7262, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_150_1/Brats18_TCIA01_150_1',)
# tensor(23.2037, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ANZ_1/Brats18_CBICA_ANZ_1',)
# tensor(14.7426, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_640_1/Brats18_TCIA10_640_1',)
# tensor(10.9699, dtype=torch.float64)
# ('HGG/Brats18_2013_10_1/Brats18_2013_10_1',)
# tensor(6.6535, dtype=torch.float64)
# ('HGG/Brats18_TCIA06_372_1/Brats18_TCIA06_372_1',)
# tensor(11.8949, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_152_1/Brats18_TCIA10_152_1',)
# tensor(16.8068, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_632_1/Brats18_TCIA10_632_1',)
# tensor(9.8060, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_299_1/Brats18_TCIA10_299_1',)
# tensor(13.6490, dtype=torch.float64)
# ('HGG/Brats18_TCIA04_479_1/Brats18_TCIA04_479_1',)
# tensor(11.3091, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_429_1/Brats18_TCIA01_429_1',)
# tensor(13.8334, dtype=torch.float64)
# ('HGG/Brats18_2013_18_1/Brats18_2013_18_1',)
# tensor(12.7508, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_628_1/Brats18_TCIA10_628_1',)
# tensor(8.5311, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_135_1/Brats18_TCIA02_135_1',)
# tensor(13.6313, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_402_1/Brats18_TCIA09_402_1',)
# tensor(10.3813, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_645_1/Brats18_TCIA13_645_1',)
# tensor(12.2598, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ANP_1/Brats18_CBICA_ANP_1',)
# tensor(13.3759, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AXN_1/Brats18_CBICA_AXN_1',)
# tensor(12.5947, dtype=torch.float64)
# ('HGG/Brats18_2013_3_1/Brats18_2013_3_1',)
# tensor(14.0581, dtype=torch.float64)
# ('HGG/Brats18_TCIA05_396_1/Brats18_TCIA05_396_1',)
# tensor(13.1446, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_208_1/Brats18_TCIA02_208_1',)
# tensor(10.9827, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_644_1/Brats18_TCIA10_644_1',)
# tensor(10.3504, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQD_1/Brats18_CBICA_AQD_1',)
# tensor(10.2965, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_314_1/Brats18_TCIA02_314_1',)
# tensor(11.3370, dtype=torch.float64)
# ('LGG/Brats18_TCIA12_101_1/Brats18_TCIA12_101_1',)
# tensor(13.3003, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_168_1/Brats18_TCIA02_168_1',)
# tensor(31.3511, dtype=torch.float64)
# ('LGG/Brats18_TCIA12_480_1/Brats18_TCIA12_480_1',)
# tensor(9.5616, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AOH_1/Brats18_CBICA_AOH_1',)
# tensor(14.3725, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_425_1/Brats18_TCIA01_425_1',)
# tensor(17.9005, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ABE_1/Brats18_CBICA_ABE_1',)
# tensor(9.5418, dtype=torch.float64)
# ('LGG/Brats18_2013_15_1/Brats18_2013_15_1',)
# tensor(10.1543, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AOZ_1/Brats18_CBICA_AOZ_1',)
# tensor(12.8484, dtype=torch.float64)
# ('HGG/Brats18_TCIA06_247_1/Brats18_TCIA06_247_1',)
# tensor(14.0776, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_448_1/Brats18_TCIA01_448_1',)
# tensor(14.1926, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AOP_1/Brats18_CBICA_AOP_1',)
# tensor(13.0043, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_498_1/Brats18_TCIA03_498_1',)
# tensor(13.9608, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASA_1/Brats18_CBICA_ASA_1',)
# tensor(9.5866, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AOO_1/Brats18_CBICA_AOO_1',)
# tensor(14.1236, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_199_1/Brats18_TCIA03_199_1',)
# tensor(19.1803, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_473_1/Brats18_TCIA02_473_1',)
# tensor(11.2119, dtype=torch.float64)
# ('HGG/Brats18_TCIA06_165_1/Brats18_TCIA06_165_1',)
# tensor(11.4262, dtype=torch.float64)
# ('HGG/Brats18_TCIA06_409_1/Brats18_TCIA06_409_1',)
# tensor(7.3971, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_274_1/Brats18_TCIA02_274_1',)
# tensor(9.2780, dtype=torch.float64)
# ('HGG/Brats18_2013_12_1/Brats18_2013_12_1',)
# tensor(8.4668, dtype=torch.float64)
# ('HGG/Brats18_TCIA05_277_1/Brats18_TCIA05_277_1',)
# tensor(17.3519, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ARF_1/Brats18_CBICA_ARF_1',)
# tensor(10.4261, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_241_1/Brats18_TCIA10_241_1',)
# tensor(10.5717, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQJ_1/Brats18_CBICA_AQJ_1',)
# tensor(10.8888, dtype=torch.float64)
# ('HGG/Brats18_CBICA_APR_1/Brats18_CBICA_APR_1',)
# tensor(10.9339, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_266_1/Brats18_TCIA10_266_1',)
# tensor(10.2944, dtype=torch.float64)
# ('HGG/Brats18_2013_19_1/Brats18_2013_19_1',)
# tensor(11.4998, dtype=torch.float64)
# ('HGG/Brats18_CBICA_APY_1/Brats18_CBICA_APY_1',)
# tensor(12.5616, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQO_1/Brats18_CBICA_AQO_1',)
# tensor(12.1175, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_179_1/Brats18_TCIA02_179_1',)
# tensor(10.3401, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_633_1/Brats18_TCIA13_633_1',)
# tensor(10.6145, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_113_1/Brats18_TCIA08_113_1',)
# tensor(11.1113, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASY_1/Brats18_CBICA_ASY_1',)
# tensor(15.1157, dtype=torch.float64)
# ('LGG/Brats18_TCIA12_466_1/Brats18_TCIA12_466_1',)
# tensor(6.4099, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_413_1/Brats18_TCIA10_413_1',)
# tensor(17.4901, dtype=torch.float64)
# ('HGG/Brats18_2013_23_1/Brats18_2013_23_1',)
# tensor(11.2751, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_650_1/Brats18_TCIA13_650_1',)
# tensor(10.4625, dtype=torch.float64)
# ('LGG/Brats18_2013_9_1/Brats18_2013_9_1',)
# tensor(10.2004, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ABO_1/Brats18_CBICA_ABO_1',)
# tensor(11.0464, dtype=torch.float64)
# ('LGG/Brats18_2013_8_1/Brats18_2013_8_1',)
# tensor(12.7378, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_255_1/Brats18_TCIA09_255_1',)
# tensor(10.6907, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_231_1/Brats18_TCIA01_231_1',)
# tensor(11.7047, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ANI_1/Brats18_CBICA_ANI_1',)
# tensor(9.9417, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_624_1/Brats18_TCIA13_624_1',)
# tensor(10.3126, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AYW_1/Brats18_CBICA_AYW_1',)
# tensor(13.6800, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_300_1/Brats18_TCIA02_300_1',)
# tensor(13.3410, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_338_1/Brats18_TCIA03_338_1',)
# tensor(13.9321, dtype=torch.float64)
# ('HGG/Brats18_TCIA05_478_1/Brats18_TCIA05_478_1',)
# tensor(10.3722, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_203_1/Brats18_TCIA01_203_1',)
# tensor(7.2022, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQU_1/Brats18_CBICA_AQU_1',)
# tensor(12.9682, dtype=torch.float64)
# ('HGG/Brats18_CBICA_BFP_1/Brats18_CBICA_BFP_1',)
# tensor(13.2897, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_491_1/Brats18_TCIA02_491_1',)
# tensor(7.2379, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_420_1/Brats18_TCIA10_420_1',)
# tensor(12.4413, dtype=torch.float64)
# ('HGG/Brats18_2013_14_1/Brats18_2013_14_1',)
# tensor(9.8444, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQQ_1/Brats18_CBICA_AQQ_1',)
# tensor(13.0449, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_331_1/Brats18_TCIA02_331_1',)
# tensor(8.1554, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_234_1/Brats18_TCIA08_234_1',)
# tensor(11.8058, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ATX_1/Brats18_CBICA_ATX_1',)
# tensor(14.2429, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AAP_1/Brats18_CBICA_AAP_1',)
# tensor(14.3119, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AUR_1/Brats18_CBICA_AUR_1',)
# tensor(12.9112, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQV_1/Brats18_CBICA_AQV_1',)
# tensor(17.5307, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_615_1/Brats18_TCIA13_615_1',)
# tensor(9.8035, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASH_1/Brats18_CBICA_ASH_1',)
# tensor(18.4396, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASE_1/Brats18_CBICA_ASE_1',)
# tensor(14.0184, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQT_1/Brats18_CBICA_AQT_1',)
# tensor(13.7000, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_411_1/Brats18_TCIA01_411_1',)
# tensor(12.5998, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_312_1/Brats18_TCIA09_312_1',)
# tensor(12.6748, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_322_1/Brats18_TCIA02_322_1',)
# tensor(16.9262, dtype=torch.float64)
# ('HGG/Brats18_TCIA04_192_1/Brats18_TCIA04_192_1',)
# tensor(8.9232, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQG_1/Brats18_CBICA_AQG_1',)
# tensor(10.7215, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_393_1/Brats18_TCIA10_393_1',)
# tensor(9.5729, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_451_1/Brats18_TCIA09_451_1',)
# tensor(13.6673, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_410_1/Brats18_TCIA10_410_1',)
# tensor(7.9137, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_374_1/Brats18_TCIA02_374_1',)
# tensor(12.6770, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_218_1/Brats18_TCIA08_218_1',)
# tensor(14.1836, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_630_1/Brats18_TCIA13_630_1',)
# tensor(8.6337, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_201_1/Brats18_TCIA01_201_1',)
# tensor(9.2184, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_419_1/Brats18_TCIA03_419_1',)
# tensor(13.9571, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_147_1/Brats18_TCIA01_147_1',)
# tensor(12.5848, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_235_1/Brats18_TCIA01_235_1',)
# tensor(9.4445, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ATF_1/Brats18_CBICA_ATF_1',)
# tensor(10.6615, dtype=torch.float64)
# ('LGG/Brats18_2013_16_1/Brats18_2013_16_1',)
# tensor(10.4488, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_346_1/Brats18_TCIA10_346_1',)
# tensor(11.7162, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_351_1/Brats18_TCIA10_351_1',)
# tensor(10.6834, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_606_1/Brats18_TCIA02_606_1',)
# tensor(17.3620, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_387_1/Brats18_TCIA10_387_1',)
# tensor(10.9552, dtype=torch.float64)
# ('LGG/Brats18_2013_29_1/Brats18_2013_29_1',)
# tensor(11.1862, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_162_1/Brats18_TCIA08_162_1',)
# tensor(9.0106, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_257_1/Brats18_TCIA03_257_1',)
# tensor(9.2794, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_499_1/Brats18_TCIA01_499_1',)
# tensor(8.0575, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AXM_1/Brats18_CBICA_AXM_1',)
# tensor(12.2733, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_623_1/Brats18_TCIA13_623_1',)
# tensor(7.9028, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_390_1/Brats18_TCIA01_390_1',)
# tensor(12.2216, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_221_1/Brats18_TCIA01_221_1',)
# tensor(11.3978, dtype=torch.float64)
# ('HGG/Brats18_TCIA03_138_1/Brats18_TCIA03_138_1',)
# tensor(13.8322, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ARW_1/Brats18_CBICA_ARW_1',)
# tensor(14.3974, dtype=torch.float64)
# ('LGG/Brats18_2013_1_1/Brats18_2013_1_1',)
# tensor(8.8005, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_378_1/Brats18_TCIA01_378_1',)
# tensor(10.2318, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AQY_1/Brats18_CBICA_AQY_1',)
# tensor(11.1267, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_310_1/Brats18_TCIA10_310_1',)
# tensor(8.7512, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_321_1/Brats18_TCIA02_321_1',)
# tensor(9.1726, dtype=torch.float64)
# ('HGG/Brats18_CBICA_BHK_1/Brats18_CBICA_BHK_1',)
# tensor(10.0704, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_642_1/Brats18_TCIA13_642_1',)
# tensor(7.7902, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ABB_1/Brats18_CBICA_ABB_1',)
# tensor(12.7570, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_430_1/Brats18_TCIA02_430_1',)
# tensor(10.0152, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_368_1/Brats18_TCIA02_368_1',)
# tensor(11.2911, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_186_1/Brats18_TCIA01_186_1',)
# tensor(11.4168, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_406_1/Brats18_TCIA08_406_1',)
# tensor(10.2822, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_401_1/Brats18_TCIA01_401_1',)
# tensor(12.6176, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_428_1/Brats18_TCIA09_428_1',)
# tensor(10.6673, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_319_1/Brats18_TCIA08_319_1',)
# tensor(12.7354, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_618_1/Brats18_TCIA13_618_1',)
# tensor(8.7640, dtype=torch.float64)
# ('HGG/Brats18_2013_26_1/Brats18_2013_26_1',)
# tensor(9.2104, dtype=torch.float64)
# ('HGG/Brats18_TCIA01_412_1/Brats18_TCIA01_412_1',)
# tensor(9.5318, dtype=torch.float64)
# ('LGG/Brats18_TCIA12_470_1/Brats18_TCIA12_470_1',)
# tensor(7.2817, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_325_1/Brats18_TCIA10_325_1',)
# tensor(10.1824, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_307_1/Brats18_TCIA10_307_1',)
# tensor(10.8012, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_462_1/Brats18_TCIA09_462_1',)
# tensor(16.7198, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ALU_1/Brats18_CBICA_ALU_1',)
# tensor(12.9295, dtype=torch.float64)
# ('HGG/Brats18_2013_17_1/Brats18_2013_17_1',)
# tensor(8.7849, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AAG_1/Brats18_CBICA_AAG_1',)
# tensor(10.3039, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASU_1/Brats18_CBICA_ASU_1',)
# tensor(11.5229, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_639_1/Brats18_TCIA10_639_1',)
# tensor(11.3613, dtype=torch.float64)
# ('HGG/Brats18_2013_5_1/Brats18_2013_5_1',)
# tensor(9.1825, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ATB_1/Brats18_CBICA_ATB_1',)
# tensor(12.9259, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_261_1/Brats18_TCIA10_261_1',)
# tensor(10.1107, dtype=torch.float64)
# ('HGG/Brats18_2013_21_1/Brats18_2013_21_1',)
# tensor(8.0751, dtype=torch.float64)
# ('HGG/Brats18_TCIA04_343_1/Brats18_TCIA04_343_1',)
# tensor(14.6913, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASO_1/Brats18_CBICA_ASO_1',)
# tensor(12.2031, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_455_1/Brats18_TCIA02_455_1',)
# tensor(12.1703, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AZD_1/Brats18_CBICA_AZD_1',)
# tensor(11.1645, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AXL_1/Brats18_CBICA_AXL_1',)
# tensor(14.8336, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASK_1/Brats18_CBICA_ASK_1',)
# tensor(11.6884, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ASN_1/Brats18_CBICA_ASN_1',)
# tensor(11.8275, dtype=torch.float64)
# ('LGG/Brats18_TCIA12_298_1/Brats18_TCIA12_298_1',)
# tensor(14.2398, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_283_1/Brats18_TCIA02_283_1',)
# tensor(9.2829, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_109_1/Brats18_TCIA10_109_1',)
# tensor(16.8202, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_151_1/Brats18_TCIA02_151_1',)
# tensor(15.4286, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_141_1/Brats18_TCIA09_141_1',)
# tensor(15.3036, dtype=torch.float64)
# ('HGG/Brats18_2013_11_1/Brats18_2013_11_1',)
# tensor(8.8085, dtype=torch.float64)
# ('HGG/Brats18_CBICA_ABN_1/Brats18_CBICA_ABN_1',)
# tensor(10.0854, dtype=torch.float64)
# ('HGG/Brats18_TCIA06_332_1/Brats18_TCIA06_332_1',)
# tensor(14.0008, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_202_1/Brats18_TCIA10_202_1',)
# tensor(7.0706, dtype=torch.float64)
# ('HGG/Brats18_TCIA02_290_1/Brats18_TCIA02_290_1',)
# tensor(8.0018, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_278_1/Brats18_TCIA08_278_1',)
# tensor(9.9315, dtype=torch.float64)
# ('LGG/Brats18_TCIA10_490_1/Brats18_TCIA10_490_1',)
# tensor(11.6619, dtype=torch.float64)
# ('LGG/Brats18_TCIA09_177_1/Brats18_TCIA09_177_1',)
# tensor(9.8816, dtype=torch.float64)
# ('LGG/Brats18_TCIA13_653_1/Brats18_TCIA13_653_1',)
# tensor(9.3849, dtype=torch.float64)
# ('HGG/Brats18_TCIA08_105_1/Brats18_TCIA08_105_1',)
# tensor(10.0163, dtype=torch.float64)
# ('HGG/Brats18_CBICA_AYU_1/Brats18_CBICA_AYU_1',)
# tensor(12.3698, dtype=torch.float64)
